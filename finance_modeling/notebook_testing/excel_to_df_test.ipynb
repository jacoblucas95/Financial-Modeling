# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('nvda-q.xlsx')
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#     Data provided by SimFin                                       Unnamed: 1  \
# 1   Profit & Loss statement                                              NaN
# 2                       NaN                                   in million USD
# 3                       NaN                                          Revenue
# 4                       NaN                                  Cost of revenue
# 5                       NaN                                     Gross Profit
# 6                       NaN                               Operating Expenses
# 7                       NaN                          Operating Income (Loss)
# 8                       NaN                      Non-Operating Income (Loss)
# 9                       NaN                          Abnormal Gains (Losses)
# 10                      NaN                             Pretax Income (Loss)
# 11                      NaN                Income Tax (Expense) Benefit, net
# 12                      NaN      Net Income Available to Common Shareholders
# 14            Balance Sheet                                              NaN
# 15                      NaN                                   in million USD
# 16                      NaN                                           Assets
# 17                      NaN  Cash, Cash Equivalents & Short Term Investments
# 18                      NaN                      Accounts & Notes Receivable
# 19                      NaN                                      Inventories
# 20                      NaN                          Other Short Term Assets
# 21                      NaN                             Total Current Assets
# 22                      NaN                 Property, Plant & Equipment, Net
# 23                      NaN                           Other Long Term Assets
# 24                      NaN                          Total Noncurrent Assets
# 25                      NaN                                     Total Assets
# 26                      NaN                                      Liabilities
# 27                      NaN                              Payables & Accruals
# 28                      NaN                                  Short Term Debt
# 29                      NaN                     Other Short Term Liabilities
# 30                      NaN                        Total Current Liabilities
# 31                      NaN                                   Long Term Debt
# 32                      NaN                      Other Long Term Liabilities
# 33                      NaN                     Total Noncurrent Liabilities
# 34                      NaN                                Total Liabilities
# 35                      NaN                                 Preferred Equity
# 36                      NaN       Share Capital & Additional Paid-In Capital
# 37                      NaN                                   Treasury Stock
# 38                      NaN                                Retained Earnings
# 39                      NaN                                     Other Equity
# 40                      NaN                  Equity Before Minority Interest
# 41                      NaN                                     Total Equity
# 42                      NaN                       Total Liabilities & Equity
# 44      Cash Flow statement                                              NaN
# 45                      NaN                                   in million USD
# 46                      NaN                         Net Income/Starting Line
# 47                      NaN                      Depreciation & Amortization
# 48                      NaN                                   Non-Cash Items
# 49                      NaN                        Change in Working Capital
# 50                      NaN                   Cash from Operating Activities
# 51                      NaN             Change in Fixed Assets & Intangibles
# 52                      NaN               Net Change in Long Term Investment
# 53                      NaN                       Other Investing Activities
# 54                      NaN                   Cash from Investing Activities
# 55                      NaN                                   Dividends Paid
# 56                      NaN                    Cash From (Repayment of) Debt
# 57                      NaN                 Cash From (Repurchase of) Equity
# 58                      NaN                       Other Financing Activities
# 59                      NaN                   Cash from Financing Activities
# 60                      NaN                              Net Changes in Cash
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2      Q2 '17     Q3 '17     Q4 '17     Q1 '18     Q2 '18     Q3 '18
# 3        2230       2636       2911       3207       3123       3181
# 4        -928      -1067      -1110      -1139      -1148      -1260
# 5        1302       1569       1801       2068       1975       1921
# 6        -614       -674       -728       -773       -818       -863
# 7         688        895       1073       1295       1157       1058
# 8          -4          1          7         16         23         23
# 9           0          0          0        NaN        NaN        NaN
# 10        684        896       1080       1311       1180       1081
# 11       -101        -58         39        -67        -79        149
# 12        583        838       1119       1244       1101       1230
# 14        NaN        NaN        NaN        NaN        NaN        NaN
# 15     Q2 '17     Q3 '17     Q4 '17     Q1 '18     Q2 '18     Q3 '18
# 16        NaN        NaN        NaN        NaN        NaN        NaN
# 17       5877       6320       7108       7300       7943       7591
# 18       1213       1167       1265       1220       1662       2219
# 19        855        857        796        797       1090       1417
# 20        125        135         86        131        136        159
# 21       8070       8479       9255       9448      10831      11386
# 22        578        600        997       1066       1162       1292
# 23        754        751        989        946        889        979
# 24       1332       1351       1986       2012       2051       2271
# 25       9402       9830      11241      11460      12882      13657
# 26        NaN        NaN        NaN        NaN        NaN        NaN
# 27        431        511        596        623        800        902
# 28         84         23         15         14         14          3
# 29        517        493        542        469        648        703
# 30       1032       1027       1153       1106       1462       1608
# 31       1987       1986       1985       1986       1987       1987
# 32        410        465        632        651        638        587
# 33       2397       2451       2617       2637       2625       2574
# 34       3429       3478       3770       3743       4087       4182
# 35          0          0          0          0          0          0
# 36       5049       5220       5352       5547       5682       5892
# 37      -6070      -6614      -6650      -7755      -7821      -8489
# 38       7006       7760       8787       9948      10957      12096
# 39        -12        -14        -18        -23        -23        -24
# 40       5973       6352       7471       7717       8795       9475
# 41       5973       6352       7471       7717       8795       9475
# 42       9402       9830      11241      11460      12882      13657
# 44        NaN        NaN        NaN        NaN        NaN        NaN
# 45     Q2 '17     Q3 '17     Q4 '17     Q1 '18     Q2 '18     Q3 '18
# 46        584        837       1119       1244       1101       1230
# 47         49         49         54         57         59         68
# 48        182        156       -386        172        181         42
# 49       -110        115        571        -28       -428       -853
# 50        705       1157       1358       1445        913        487
# 51        -54        -69       -416       -118       -129       -150
# 52        327        365        400      -3433       -669        371
# 53        -11        -10         -8          0         -7         -2
# 54        262        286        -24      -3551       -805        219
# 55        -84        -84        -91        -91        -91        -91
# 56       -136        -62         -9         -2          0        -10
# 57       -758       -151          0       -655          0       -200
# 58         10       -332        -34       -383        -64       -402
# 59       -968       -629       -134      -1131       -155       -703
# 60         -1        814       1200      -3237        -47          3
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 1         NaN        NaN         NaN         NaN
# 2      Q4 '18     Q1 '19      Q2 '19      Q3 '19
# 3        2205       2220        2579        3014
# 4        -998       -924       -1038       -1098
# 5        1207       1296        1541        1916
# 6        -913       -938        -970        -989
# 7         294        358         571         927
# 8          30         31          35          32
# 9           0        NaN         NaN         NaN
# 10        324        389         606         959
# 11        242          5         -54         -60
# 12        566        394         552         899
# 14        NaN        NaN         NaN         NaN
# 15     Q4 '18     Q1 '19      Q2 '19      Q3 '19
# 16        NaN        NaN         NaN         NaN
# 17       7422       7802        8475        9769
# 18       1424       1242        1561        1455
# 19       1575       1426        1204        1047
# 20        136        159         151         149
# 21      10557      10629       11391       12420
# 22       1404       1473        1484        1517
# 23       1331       1919        1900        1873
# 24       2735       3392        3384        3390
# 25      13292      14021       14775       15810
# 26        NaN        NaN         NaN         NaN
# 27        511        368         437         591
# 28        NaN        NaN         NaN         NaN
# 29        818        815         880         884
# 30       1329       1183        1317        1475
# 31       1988       2474        1989        1990
# 32        633        660        1133        1131
# 33       2621       3134        3122        3121
# 34       3950       4317        4439        4596
# 35          0          0           0           0
# 36       6052       6318        6544        6825
# 37      -9263      -9474       -9524       -9726
# 38      12565      12862       13317       14118
# 39        -12         -2          -1          -3
# 40       9342       9704       10336       11214
# 41       9342       9704       10336       11214
# 42      13292      14021       14775       15810
# 44        NaN        NaN         NaN         NaN
# 45     Q4 '18     Q1 '19      Q2 '19      Q3 '19
# 46        566        394         553         898
# 47         78         91          92          92
# 48       -198        134         241         249
# 49        452        101          50         401
# 50        898        720         936        1640
# 51       -203       -128        -113        -103
# 52        243       1623        3660        1363
# 53          0        NaN          -2          -4
# 54         40       1495        3545        1256
# 55        -98        -97         -98         -97
# 56         -4          0          83          63
# 57       -724          0           0         NaN
# 58        -51       -128        -133        -202
# 59       -877       -225        -148        -236
# 60         61       1990        4333        2660

# %%
index_pl = df.loc[df['Data provided by SimFin'] == 'Profit & Loss statement'].index[0]
index_cf = df.loc[df['Data provided by SimFin'] == 'Cash Flow statement'].index[0]
index_bs = df.loc[df['Data provided by SimFin'] == 'Balance Sheet'].index[0]

# %%
df_pl = df.iloc[index_pl:index_bs-2, 1:]
df_cf = df.iloc[index_cf-2:, 1:]
df_bs = df.iloc[index_bs-1:index_cf-3, 1:]

# %%
# P/L DF
df_pl.columns = df_pl.iloc[0]
df_pl.set_index('in million USD',inplace=True)
df_pl.fillna(0, inplace=True)
df_pl.drop(df_pl.index[0], inplace=True)
df_pl = df_pl.T
df_pl
# Out:
# in million USD Revenue Cost of revenue Gross Profit Operating Expenses  \
# 2
# Q2 '17            2230            -928         1302               -614
# Q3 '17            2636           -1067         1569               -674
# Q4 '17            2911           -1110         1801               -728
# Q1 '18            3207           -1139         2068               -773
# Q2 '18            3123           -1148         1975               -818
# Q3 '18            3181           -1260         1921               -863
# Q4 '18            2205            -998         1207               -913
# Q1 '19            2220            -924         1296               -938
# Q2 '19            2579           -1038         1541               -970
# Q3 '19            3014           -1098         1916               -989
#
# in million USD Operating Income (Loss) Non-Operating Income (Loss)  \
# 2
# Q2 '17                             688                          -4
# Q3 '17                             895                           1
# Q4 '17                            1073                           7
# Q1 '18                            1295                          16
# Q2 '18                            1157                          23
# Q3 '18                            1058                          23
# Q4 '18                             294                          30
# Q1 '19                             358                          31
# Q2 '19                             571                          35
# Q3 '19                             927                          32
#
# in million USD Abnormal Gains (Losses) Pretax Income (Loss)  \
# 2
# Q2 '17                               0                  684
# Q3 '17                               0                  896
# Q4 '17                               0                 1080
# Q1 '18                               0                 1311
# Q2 '18                               0                 1180
# Q3 '18                               0                 1081
# Q4 '18                               0                  324
# Q1 '19                               0                  389
# Q2 '19                               0                  606
# Q3 '19                               0                  959
#
# in million USD Income Tax (Expense) Benefit, net  \
# 2
# Q2 '17                                      -101
# Q3 '17                                       -58
# Q4 '17                                        39
# Q1 '18                                       -67
# Q2 '18                                       -79
# Q3 '18                                       149
# Q4 '18                                       242
# Q1 '19                                         5
# Q2 '19                                       -54
# Q3 '19                                       -60
#
# in million USD Net Income Available to Common Shareholders
# 2
# Q2 '17                                                 583
# Q3 '17                                                 838
# Q4 '17                                                1119
# Q1 '18                                                1244
# Q2 '18                                                1101
# Q3 '18                                                1230
# Q4 '18                                                 566
# Q1 '19                                                 394
# Q2 '19                                                 552
# Q3 '19                                                 899

# %%
# CF DF
df_cf.columns = df_cf.iloc[0]
df_cf.set_index('in million USD', inplace=True)
df_cf.fillna(0, inplace=True)
df_cf.drop(df_cf.index[0], inplace=True)
df_cf = df_cf.T
df_cf
# Out:
# in million USD Net Income/Starting Line Depreciation & Amortization  \
# 45
# Q2 '17                              584                          49
# Q3 '17                              837                          49
# Q4 '17                             1119                          54
# Q1 '18                             1244                          57
# Q2 '18                             1101                          59
# Q3 '18                             1230                          68
# Q4 '18                              566                          78
# Q1 '19                              394                          91
# Q2 '19                              553                          92
# Q3 '19                              898                          92
#
# in million USD Non-Cash Items Change in Working Capital  \
# 45
# Q2 '17                    182                      -110
# Q3 '17                    156                       115
# Q4 '17                   -386                       571
# Q1 '18                    172                       -28
# Q2 '18                    181                      -428
# Q3 '18                     42                      -853
# Q4 '18                   -198                       452
# Q1 '19                    134                       101
# Q2 '19                    241                        50
# Q3 '19                    249                       401
#
# in million USD Cash from Operating Activities  \
# 45
# Q2 '17                                    705
# Q3 '17                                   1157
# Q4 '17                                   1358
# Q1 '18                                   1445
# Q2 '18                                    913
# Q3 '18                                    487
# Q4 '18                                    898
# Q1 '19                                    720
# Q2 '19                                    936
# Q3 '19                                   1640
#
# in million USD Change in Fixed Assets & Intangibles  \
# 45
# Q2 '17                                          -54
# Q3 '17                                          -69
# Q4 '17                                         -416
# Q1 '18                                         -118
# Q2 '18                                         -129
# Q3 '18                                         -150
# Q4 '18                                         -203
# Q1 '19                                         -128
# Q2 '19                                         -113
# Q3 '19                                         -103
#
# in million USD Net Change in Long Term Investment Other Investing Activities  \
# 45
# Q2 '17                                        327                        -11
# Q3 '17                                        365                        -10
# Q4 '17                                        400                         -8
# Q1 '18                                      -3433                          0
# Q2 '18                                       -669                         -7
# Q3 '18                                        371                         -2
# Q4 '18                                        243                          0
# Q1 '19                                       1623                          0
# Q2 '19                                       3660                         -2
# Q3 '19                                       1363                         -4
#
# in million USD Cash from Investing Activities Dividends Paid  \
# 45
# Q2 '17                                    262            -84
# Q3 '17                                    286            -84
# Q4 '17                                    -24            -91
# Q1 '18                                  -3551            -91
# Q2 '18                                   -805            -91
# Q3 '18                                    219            -91
# Q4 '18                                     40            -98
# Q1 '19                                   1495            -97
# Q2 '19                                   3545            -98
# Q3 '19                                   1256            -97
#
# in million USD Cash From (Repayment of) Debt Cash From (Repurchase of) Equity  \
# 45
# Q2 '17                                  -136                             -758
# Q3 '17                                   -62                             -151
# Q4 '17                                    -9                                0
# Q1 '18                                    -2                             -655
# Q2 '18                                     0                                0
# Q3 '18                                   -10                             -200
# Q4 '18                                    -4                             -724
# Q1 '19                                     0                                0
# Q2 '19                                    83                                0
# Q3 '19                                    63                                0
#
# in million USD Other Financing Activities Cash from Financing Activities  \
# 45
# Q2 '17                                 10                           -968
# Q3 '17                               -332                           -629
# Q4 '17                                -34                           -134
# Q1 '18                               -383                          -1131
# Q2 '18                                -64                           -155
# Q3 '18                               -402                           -703
# Q4 '18                                -51                           -877
# Q1 '19                               -128                           -225
# Q2 '19                               -133                           -148
# Q3 '19                               -202                           -236
#
# in million USD Net Changes in Cash
# 45
# Q2 '17                          -1
# Q3 '17                         814
# Q4 '17                        1200
# Q1 '18                       -3237
# Q2 '18                         -47
# Q3 '18                           3
# Q4 '18                          61
# Q1 '19                        1990
# Q2 '19                        4333
# Q3 '19                        2660

# %%
# Balance Sheet DF
df_bs.columns = df_bs.iloc[0]
df_bs.set_index('in million USD', inplace=True)
df_bs.fillna(0, inplace=True)
df_bs.drop(df_bs.index[0], inplace=True)
df_bs
df_bs
# Out:
# 15                                              Q2 '17 Q3 '17 Q4 '17 Q1 '18  \
# in million USD
# Assets                                               0      0      0      0
# Cash, Cash Equivalents & Short Term Investments   5877   6320   7108   7300
# Accounts & Notes Receivable                       1213   1167   1265   1220
# Inventories                                        855    857    796    797
# Other Short Term Assets                            125    135     86    131
# Total Current Assets                              8070   8479   9255   9448
# Property, Plant & Equipment, Net                   578    600    997   1066
# Other Long Term Assets                             754    751    989    946
# Total Noncurrent Assets                           1332   1351   1986   2012
# Total Assets                                      9402   9830  11241  11460
# Liabilities                                          0      0      0      0
# Payables & Accruals                                431    511    596    623
# Short Term Debt                                     84     23     15     14
# Other Short Term Liabilities                       517    493    542    469
# Total Current Liabilities                         1032   1027   1153   1106
# Long Term Debt                                    1987   1986   1985   1986
# Other Long Term Liabilities                        410    465    632    651
# Total Noncurrent Liabilities                      2397   2451   2617   2637
# Total Liabilities                                 3429   3478   3770   3743
# Preferred Equity                                     0      0      0      0
# Share Capital & Additional Paid-In Capital        5049   5220   5352   5547
# Treasury Stock                                   -6070  -6614  -6650  -7755
# Retained Earnings                                 7006   7760   8787   9948
# Other Equity                                       -12    -14    -18    -23
# Equity Before Minority Interest                   5973   6352   7471   7717
# Total Equity                                      5973   6352   7471   7717
# Total Liabilities & Equity                        9402   9830  11241  11460
#
# 15                                              Q2 '18 Q3 '18 Q4 '18 Q1 '19  \
# in million USD
# Assets                                               0      0      0      0
# Cash, Cash Equivalents & Short Term Investments   7943   7591   7422   7802
# Accounts & Notes Receivable                       1662   2219   1424   1242
# Inventories                                       1090   1417   1575   1426
# Other Short Term Assets                            136    159    136    159
# Total Current Assets                             10831  11386  10557  10629
# Property, Plant & Equipment, Net                  1162   1292   1404   1473
# Other Long Term Assets                             889    979   1331   1919
# Total Noncurrent Assets                           2051   2271   2735   3392
# Total Assets                                     12882  13657  13292  14021
# Liabilities                                          0      0      0      0
# Payables & Accruals                                800    902    511    368
# Short Term Debt                                     14      3      0      0
# Other Short Term Liabilities                       648    703    818    815
# Total Current Liabilities                         1462   1608   1329   1183
# Long Term Debt                                    1987   1987   1988   2474
# Other Long Term Liabilities                        638    587    633    660
# Total Noncurrent Liabilities                      2625   2574   2621   3134
# Total Liabilities                                 4087   4182   3950   4317
# Preferred Equity                                     0      0      0      0
# Share Capital & Additional Paid-In Capital        5682   5892   6052   6318
# Treasury Stock                                   -7821  -8489  -9263  -9474
# Retained Earnings                                10957  12096  12565  12862
# Other Equity                                       -23    -24    -12     -2
# Equity Before Minority Interest                   8795   9475   9342   9704
# Total Equity                                      8795   9475   9342   9704
# Total Liabilities & Equity                       12882  13657  13292  14021
#
# 15                                              Q2 '19 Q3 '19
# in million USD
# Assets                                               0      0
# Cash, Cash Equivalents & Short Term Investments   8475   9769
# Accounts & Notes Receivable                       1561   1455
# Inventories                                       1204   1047
# Other Short Term Assets                            151    149
# Total Current Assets                             11391  12420
# Property, Plant & Equipment, Net                  1484   1517
# Other Long Term Assets                            1900   1873
# Total Noncurrent Assets                           3384   3390
# Total Assets                                     14775  15810
# Liabilities                                          0      0
# Payables & Accruals                                437    591
# Short Term Debt                                      0      0
# Other Short Term Liabilities                       880    884
# Total Current Liabilities                         1317   1475
# Long Term Debt                                    1989   1990
# Other Long Term Liabilities                       1133   1131
# Total Noncurrent Liabilities                      3122   3121
# Total Liabilities                                 4439   4596
# Preferred Equity                                     0      0
# Share Capital & Additional Paid-In Capital        6544   6825
# Treasury Stock                                   -9524  -9726
# Retained Earnings                                13317  14118
# Other Equity                                        -1     -3
# Equity Before Minority Interest                  10336  11214
# Total Equity                                     10336  11214
# Total Liabilities & Equity                       14775  15810
